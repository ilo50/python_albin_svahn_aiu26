# %% [markdown]
# # Exercise 3 - sequences
#
# In this exercise, you get to familiarize yourself with sequences in Python.
# # 0. Dice rolls (*)
#
# Simulate 10 dice rolls and append the rolls to a list. Do this once again but now use list comprehension instead to create the list.

# %%
import random

list = []

for n in range(10):

    val = random.randrange(1, 7)
    list.append(val)

print(list)

# 

new_list = []

for x in list:
    new_list.append(x)

print(new_list)
# Out:
# [6, 1, 2, 6, 3, 5, 5, 6, 6, 3]
# [6, 1, 2, 6, 3, 5, 5, 6, 6, 3]

# %% [markdown]
# a) sort the list in ascending order (*)

# %%
sorted_list = list.copy()

sorted_list.sort()
print(sorted_list)
print(list)
# Out:
# [1, 2, 3, 3, 5, 5, 6, 6, 6, 6]
# [6, 1, 2, 6, 3, 5, 5, 6, 6, 3]

# %% [markdown]
# b) sort the list in descending order (*)

# %%
sorted_list = list.copy()

sorted_list.sort()
sorted_list.reverse()
print(sorted_list)
# Out:
# [6, 6, 6, 6, 5, 5, 3, 3, 2, 1]

# %% [markdown]
# c) find the maximum and minimum value in the list (*)

# %%
max_val = max(new_list)
min_val = min(new_list)

print(f"max:{max_val}, min:{min_val}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 new_list = list.copy()
#       2
# ----> 3 max_val = max(new_list)
#       4 min_val = min(new_list)
#       5
#       6 print(f"max:{max_val}, min:{min_val}")
#
# TypeError: 'int' object is not callable

# %% [markdown]
# d) calculate the mean (average) of the list (*)

# %% [markdown]
# e) find the median of the list (*)

# %% [markdown]
# f) extract only the unique values from the list. The output should be a list (*)
